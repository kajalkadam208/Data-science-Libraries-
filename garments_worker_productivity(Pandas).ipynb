# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\Datasets\garments_worker_productivity.csv")

# %%
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# # Information of dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %% [markdown]
# # Describe dataset

# %%
dataset.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# # Null values

# %%
dataset.isnull().any()
# Out:
# date                     False
# quarter                  False
# department               False
# day                      False
# team                     False
# targeted_productivity    False
# smv                      False
# wip                       True
# over_time                False
# incentive                False
# idle_time                False
# idle_men                 False
# no_of_style_change       False
# no_of_workers            False
# actual_productivity      False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %% [markdown]
# # iloc

# %%
dataset.iloc[1:1000,10:]
# Out:
#      idle_time  idle_men  no_of_style_change  no_of_workers  \
# 1          0.0         0                   0            8.0
# 2          0.0         0                   0           30.5
# 3          0.0         0                   0           30.5
# 4          0.0         0                   0           56.0
# 5          0.0         0                   0           56.0
# ..         ...       ...                 ...            ...
# 995        0.0         0                   0           58.0
# 996        4.0        20                   0           57.0
# 997        0.0         0                   0            8.0
# 998        0.0         0                   0            8.0
# 999        0.0         0                   0           57.0
#
#      actual_productivity
# 1               0.886500
# 2               0.800570
# 3               0.800570
# 4               0.800382
# 5               0.800125
# ..                   ...
# 995             0.683551
# 996             0.682433
# ...

# %% [markdown]
# # loc

# %%
dataset["team"].unique()
# Out:
# array([ 8,  1, 11, 12,  6,  7,  2,  3,  9, 10,  5,  4], dtype=int64)

# %%
x=dataset.loc[(dataset["no_of_workers"]>30) & (dataset["team"]>3),["no_of_workers","team"]]
x
# Out:
#       no_of_workers  team
# 0              59.0     8
# 2              30.5    11
# 3              30.5    12
# 4              56.0     6
# 5              56.0     7
# ...             ...   ...
# 1187           59.0     4
# 1188           58.0     5
# 1189           57.0     8
# 1190           38.0     6
# 1191           57.0     7
#
# [516 rows x 2 columns]

# %%
x["team"].unique()
# Out:
# array([ 8, 11, 12,  6,  7,  9, 10,  5,  4], dtype=int64)

# %% [markdown]
# # Count all rows

# %%
dataset["targeted_productivity"].value_counts()
# Out:
# 0.80    540
# 0.70    242
# 0.75    216
# 0.65     63
# 0.60     57
# 0.50     49
# 0.35     27
# 0.40      2
# 0.07      1
# Name: targeted_productivity, dtype: int64

# %%
dataset.values
# Out:
# array([['1/1/2015', 'Quarter1', 'sweing', ..., 0, 59.0, 0.940725424],
#        ['1/1/2015', 'Quarter1', 'finishing ', ..., 0, 8.0, 0.8865],
#        ['1/1/2015', 'Quarter1', 'sweing', ..., 0, 30.5, 0.800570492],
#        ...,
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 8.0, 0.625625],
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 15.0, 0.505888889],
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 6.0, 0.394722222]],
#       dtype=object)

# %%
dataset["over_time"].value_counts()
# Out:
# 960      129
# 1440     111
# 6960      61
# 6840      48
# 1200      39
#         ...
# 4140       1
# 12180      1
# 10770      1
# 12000      1
# 3120       1
# Name: over_time, Length: 143, dtype: int64

# %%
dataset.values
# Out:
# array([['1/1/2015', 'Quarter1', 'sweing', ..., 0, 59.0, 0.940725424],
#        ['1/1/2015', 'Quarter1', 'finishing ', ..., 0, 8.0, 0.8865],
#        ['1/1/2015', 'Quarter1', 'sweing', ..., 0, 30.5, 0.800570492],
#        ...,
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 8.0, 0.625625],
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 15.0, 0.505888889],
#        ['3/11/2015', 'Quarter2', 'finishing', ..., 0, 6.0, 0.394722222]],
#       dtype=object)

# %% [markdown]
# # Replace

# %%
dataset
# Out:
#            date   quarter  department   day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing  None     8                   0.80
# 1      1/1/2015  Quarter1  finishing   None     1                   0.75
# 2      1/1/2015  Quarter1      sweing  None    11                   0.80
# 3      1/1/2015  Quarter1      sweing  None    12                   0.80
# 4      1/1/2015  Quarter1      sweing  None     6                   0.80
# ...         ...       ...         ...   ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  None    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  None     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  None     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  None     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  None     6                   0.70
#
#         smv     wip  over_time  incentive  idle_time  idle_men  \
# ...

# %%
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
x=dataset["day"].replace("Thursday","itsday",inplace=True)

# %%
x

# %%
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing     itsday     8                   0.80
# 1      1/1/2015  Quarter1  finishing      itsday     1                   0.75
# 2      1/1/2015  Quarter1      sweing     itsday    11                   0.80
# 3      1/1/2015  Quarter1      sweing     itsday    12                   0.80
# 4      1/1/2015  Quarter1      sweing     itsday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# # Drop

# %%
d=dataset.drop(columns="actual_productivity")

# %%
d
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing     itsday     8                   0.80
# 1      1/1/2015  Quarter1  finishing      itsday     1                   0.75
# 2      1/1/2015  Quarter1      sweing     itsday    11                   0.80
# 3      1/1/2015  Quarter1      sweing     itsday    12                   0.80
# 4      1/1/2015  Quarter1      sweing     itsday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# # Fillna

# %%
e=dataset["wip"].min()
e
# Out:
# 7.0

# %%
ab=dataset["wip"].fillna(e,inplace=True)

# %%
ab

# %%
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing     itsday     8                   0.80
# 1      1/1/2015  Quarter1  finishing      itsday     1                   0.75
# 2      1/1/2015  Quarter1      sweing     itsday    11                   0.80
# 3      1/1/2015  Quarter1      sweing     itsday    12                   0.80
# 4      1/1/2015  Quarter1      sweing     itsday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# # Show particular columns

# %%
dataset[["department","day","team","targeted_productivity"]]
# Out:
#       department        day  team  targeted_productivity
# 0         sweing     itsday     8                   0.80
# 1     finishing      itsday     1                   0.75
# 2         sweing     itsday    11                   0.80
# 3         sweing     itsday    12                   0.80
# 4         sweing     itsday     6                   0.80
# ...          ...        ...   ...                    ...
# 1192   finishing  Wednesday    10                   0.75
# 1193   finishing  Wednesday     8                   0.70
# 1194   finishing  Wednesday     7                   0.65
# 1195   finishing  Wednesday     9                   0.75
# 1196   finishing  Wednesday     6                   0.70
#
# [1197 rows x 4 columns]

# %% [markdown]
# # Show particular rows and columns

# %%
dataset.loc[[1,10,100,200,300,50],["department","day","team","targeted_productivity"]]
# Out:
#      department      day  team  targeted_productivity
# 1    finishing    itsday     1                   0.75
# 10       sweing   itsday     9                   0.70
# 100      sweing  Tuesday    11                   0.75
# 200      sweing   Monday     7                   0.80
# 300  finishing    Sunday    11                   0.65
# 50       sweing   Sunday     2                   0.80
